# %% [markdown]
# Capitulo 5
# a)Realizar todos los ejercicios propuestos del libro

# %% [markdown]
# **User-Defined Functions**

# %%
# %scala
// In Scala
// Create cubed function
val cubed = (s: Long) => {
 s * s * s
}
// Register UDF
spark.udf.register("cubed", cubed)
// Create temporary view
spark.range(1, 9).createOrReplaceTempView("udf_test")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# In Python
from pyspark.sql.types import LongType
# Create cubed function
def cubed(s):
 return s * s * s
# Register UDF
spark.udf.register("cubed", cubed, LongType())
# Generate temporary view
spark.range(1, 9).createOrReplaceTempView("udf_test")

# %%
spark.sql("SELECT id, cubed(id) AS id_cubed FROM udf_test").show()
# Out:
# +---+--------+
# | id|id_cubed|
# +---+--------+
# |  1|       1|
# |  2|       8|
# |  3|      27|
# |  4|      64|
# |  5|     125|
# |  6|     216|
# |  7|     343|
# |  8|     512|
# +---+--------+

# %% [markdown]
# Evaluation order and null checking in Spark SQL
# 1. Make the UDF itself null-aware and do null checking inside the UDF.
# 2. Use IF or CASE WHEN expressions to do the null check and invoke the UDF in a
# conditional branch.

# %% [markdown]
# scalar Pandas UDF for Spark 3.0:

# %%
# In Python
# Import pandas
import pandas as pd
# Import various pyspark SQL functions including pandas_udf
from pyspark.sql.functions import col, pandas_udf
from pyspark.sql.types import LongType
# Declare the cubed function 
def cubed(a: pd.Series) -> pd.Series:
 return a * a * a
# Create the pandas UDF for the cubed function 
cubed_udf = pandas_udf(cubed, returnType=LongType())


# Create a Pandas Series
x = pd.Series([1, 2, 3])
# The function for a pandas_udf executed with local Pandas data
print(cubed(x))
# Out:
# 0     1
# 1     8
# 2    27
# dtype: int64

# %% [markdown]
# Now let’s switch to a Spark DataFrame. We can execute this function as a Spark vec‐
# torized UDF as follows

# %%
# Create a Spark DataFrame, 'spark' is an existing SparkSession
df = spark.range(1, 4)
# Execute function as a Spark vectorized UDF
df.select("id", cubed_udf(col("id"))).show()
# Out:
# +---+---------+
# | id|cubed(id)|
# +---+---------+
# |  1|        1|
# |  2|        8|
# |  3|       27|
# +---+---------+

# %% [markdown]
# **SQL**

# %%
# %sql
CREATE TABLE gente (name STRING, age int);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW TABLES;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>gente</td><td>false</td></tr><tr><td></td><td>udf_test</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
INSERT INTO gente VALUES ("Michael", NULL);
INSERT INTO gente VALUES ("Andy", 30);
INSERT INTO gente VALUES ("Samantha", 19);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM gente where age < 20
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# com.databricks.backend.common.rpc.DatabricksExceptions$SQLExecutionException: org.apache.spark.sql.AnalysisException: Table or view not found: gente; line 1 pos 14;
# 'Project [*]
# +- 'Filter ('age < 20)
#    +- 'UnresolvedRelation [gente], [], false
#
# 	at org.apache.spark.sql.catalyst.analysis.package$AnalysisErrorAt.failAnalysis(package.scala:42)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis$2(CheckAnalysis.scala:137)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis$2$adapted(CheckAnalysis.scala:104)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:348)
# ...

# %%
# %sql
SELECT name FROM gente WHERE age IS NULL;
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# com.databricks.backend.common.rpc.DatabricksExceptions$SQLExecutionException: org.apache.spark.sql.AnalysisException: Table or view not found: people; line 1 pos 17;
# 'Project ['name]
# +- 'Filter isnull('age)
#    +- 'UnresolvedRelation [people], [], false
#
# 	at org.apache.spark.sql.catalyst.analysis.package$AnalysisErrorAt.failAnalysis(package.scala:42)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis$2(CheckAnalysis.scala:137)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis$2$adapted(CheckAnalysis.scala:104)
# ...

# %% [markdown]
# **Conectarse a BD externas**

# %% [markdown]
# **PostfreSQL**

# %%
# %scala
val jdbcDF1 = spark.read.format("jdbc")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">jdbcDF1: org.apache.spark.sql.DataFrameReader = org.apache.spark.sql.DataFrameReader@31f93540
# </div>

# %% [markdown]
# Cargar con spark datos de empleados y departamentos

# %% [markdown]
# UDF PROS Y CONTRAS:
#
# Permiten una programación modular, lo que supone un código mejor estructurado, más limpio y por lo tanto más funcional.
# Las UDF reducen la carga de trabajo de los dispositivos donde se ejecuta el software, pues el programa pesa menos y está más optimizado.
# También pueden ser muy útiles a la hora de reducir el tráfico de una red, ya que se reduce la complejidad de las acciones.
# Permiten reutilizar código de una forma sencilla y productiva, lo que se traduce en un menor tiempo de desarrollo.
# Facilita el mantenimiento del software y la comprensión del código.

# %%
from pyspark.sql.functions import *

# %%
employees = (spark
 .read
 .format("jdbc")
 .option("url", "jdbc:mysql://localhost:3306/empleado")
 .option("driver", "com.mysql.jdbc.Driver")
 .option("dbtable", "employees")
 .option("user", "root")
 .option("password", "Root1234")
 .load())
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <command-2703056789650360> in <module>
# ----> 1 employees = (spark
#       2  .read
#       3  .format("jdbc")
#       4  .option("url", "jdbc:mysql://localhost:3306/empleado")
#       5  .option("driver", "com.mysql.jdbc.Driver")
#
# /databricks/spark/python/pyspark/sql/readwriter.py in load(self, path, format, schema, **options)
#     162             return self._df(self._jreader.load(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     163         else:
# --> 164             return self._df(self._jreader.load())
#     165
#     166     def json(self, path, schema=None, primitivesAsString=None, prefersDecimal=None,
#
# /databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# ...

# %%
jdbcDF = spark.read \
    .format("jdbc") \
    .option("url", "dbfs:/FileStore/tables/employees_partitioned.sql") \
    .option("dbtable", "schema.tablename") \
    .option("user", "root") \
    .option("password", "Root1234") \
    .load()

# %%
file_location = "dbfs:/FileStore/tables/employees_partitioned.sql"
file_type = "sql"

# CSV options
infer_schema = "false"
first_row_is_header = "false"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <command-1289228043003148> in <module>
#       8
#       9 # The applied options are for CSV files. For other file types, these will be ignored.
# ---> 10 df = spark.read.format(file_type) \
#      11   .option("inferSchema", infer_schema) \
#      12   .option("header", first_row_is_header) \
#
# /databricks/spark/python/pyspark/sql/readwriter.py in load(self, path, format, schema, **options)
#     156         self.options(**options)
#     157         if isinstance(path, str):
# --> 158             return self._df(self._jreader.load(path))
#     159         elif path is not None:
#     160             if type(path) != list:
#
# /databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# ...

# %% [markdown]
# **RANK** te da la clasificación dentro de tu partición ordenada. A los empates se les asigna el mismo rango, con el siguiente ranking (s) saltado. Por lo tanto, si tiene 3 elementos en el rango 2, el siguiente puesto en la lista sería el 5.
#
# **DENSE_RANK** nuevamente le da la clasificación dentro de su partición ordenada, pero las clasificaciones son consecutivas. No se omiten rangos si hay rangos con varios elementos.
#
# En cuanto a los nulos, depende de la cláusula ORDER BY.
